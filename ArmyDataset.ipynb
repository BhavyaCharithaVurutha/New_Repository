# %%
import pandas as pd
import numpy as np
d={'regiment': ['Nighthawks', 'Nighthawks', 'Nighthawks', 'Nighthawks', 'Dragoons', 'Dragoons', 'Dragoons', 'Dragoons', 'Scouts', 'Scouts', 'Scouts', 'Scouts'],
            'company': ['1st', '1st', '2nd', '2nd', '1st', '1st', '2nd', '2nd','1st', '1st', '2nd', '2nd'],
            'deaths': [523, 52, 25, 616, 43, 234, 523, 62, 62, 73, 37, 35],
            'battles': [5, 42, 2, 2, 4, 7, 8, 3, 4, 7, 8, 9],
            'size': [1045, 957, 1099, 1400, 1592, 1006, 987, 849, 973, 1005, 1099, 1523],
            'veterans': [1, 5, 62, 26, 73, 37, 949, 48, 48, 435, 63, 345],
            'readiness': [1, 2, 3, 3, 2, 1, 2, 3, 2, 1, 2, 3],
            'armored': [1, 0, 1, 1, 0, 1, 0, 1, 0, 0, 1, 1],
            'deserters': [4, 24, 31, 2, 3, 4, 24, 31, 2, 3, 2, 3],
            'origin': ['Arizona', 'California', 'Texas', 'Florida', 'Maine', 'Iowa', 'Alaska', 'Washington', 'Oregon', 'Wyoming', 'Louisana', 'Georgia']}
army=pd.DataFrame(data=d)
army
# Out:
#       regiment company  deaths  battles  size  veterans  readiness  armored  \
# 0   Nighthawks     1st     523        5  1045         1          1        1
# 1   Nighthawks     1st      52       42   957         5          2        0
# 2   Nighthawks     2nd      25        2  1099        62          3        1
# 3   Nighthawks     2nd     616        2  1400        26          3        1
# 4     Dragoons     1st      43        4  1592        73          2        0
# 5     Dragoons     1st     234        7  1006        37          1        1
# 6     Dragoons     2nd     523        8   987       949          2        0
# 7     Dragoons     2nd      62        3   849        48          3        1
# 8       Scouts     1st      62        4   973        48          2        0
# 9       Scouts     1st      73        7  1005       435          1        0
# 10      Scouts     2nd      37        8  1099        63          2        1
# ...

# %%
type(army)
# Out:
# pandas.core.frame.DataFrame

# %%
# Set the 'origin' colum as the index of the dataframe
df=army.set_index('origin')
df
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Texas       Nighthawks     2nd      25        2  1099        62          3
# Florida     Nighthawks     2nd     616        2  1400        26          3
# Maine         Dragoons     1st      43        4  1592        73          2
# Iowa          Dragoons     1st     234        7  1006        37          1
# Alaska        Dragoons     2nd     523        8   987       949          2
# Washington    Dragoons     2nd      62        3   849        48          3
# Oregon          Scouts     1st      62        4   973        48          2
# Wyoming         Scouts     1st      73        7  1005       435          1
# Louisana        Scouts     2nd      37        8  1099        63          2
# ...

# %%
#print only the column veterans
df['veterans']
# Out:
# origin
# Arizona         1
# California      5
# Texas          62
# Florida        26
# Maine          73
# Iowa           37
# Alaska        949
# Washington     48
# Oregon         48
# Wyoming       435
# Louisana       63
# Georgia       345
# Name: veterans, dtype: int64

# %%
#print only the columns veterans and deaths
df[["veterans","deaths"]]
# Out:
#             veterans  deaths
# origin
# Arizona            1     523
# California         5      52
# Texas             62      25
# Florida           26     616
# Maine             73      43
# Iowa              37     234
# Alaska           949     523
# Washington        48      62
# Oregon            48      62
# Wyoming          435      73
# Louisana          63      37
# Georgia          345      35

# %%
#print names of columns
df.columns
# Out:
# Index(['regiment', 'company', 'deaths', 'battles', 'size', 'veterans',
#        'readiness', 'armored', 'deserters'],
#       dtype='object')

# %%
#Select the 'deaths', 'size' and 'deserters' columns from Maine and Alaska
df.loc[['Maine','Alaska'],['deaths','size','deserters']]
# Out:
#         deaths  size  deserters
# origin
# Maine       43  1592          3
# Alaska     523   987         24

# %%
#Select the rows 3 to 7 and the columns 3 to 6 
df.iloc[3:7, 3:6]
# Out:
#          battles  size  veterans
# origin
# Florida        2  1400        26
# Maine          4  1592        73
# Iowa           7  1006        37
# Alaska         8   987       949

# %%
df.shape[0]
# Out:
# 12

# %%
#Select every row after the fourth row and all column #df.iloc[4:, :]
df.tail(8)
# Out:
#             regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Maine       Dragoons     1st      43        4  1592        73          2
# Iowa        Dragoons     1st     234        7  1006        37          1
# Alaska      Dragoons     2nd     523        8   987       949          2
# Washington  Dragoons     2nd      62        3   849        48          3
# Oregon        Scouts     1st      62        4   973        48          2
# Wyoming       Scouts     1st      73        7  1005       435          1
# Louisana      Scouts     2nd      37        8  1099        63          2
# Georgia       Scouts     2nd      35        9  1523       345          3
#
#             armored  deserters
# origin
# Maine             0          3
# Iowa              1          4
# Alaska            0         24
# Washington        1         31
# Oregon            0          2
# Wyoming           0          3
# Louisana          1          2
# Georgia           1          3

# %%
#Select every row up to the 4th row and all columns #df.iloc[:4, :]
df.head(4)
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Texas       Nighthawks     2nd      25        2  1099        62          3
# Florida     Nighthawks     2nd     616        2  1400        26          3
#
#             armored  deserters
# origin
# Arizona           1          4
# California        0         24
# Texas             1         31
# Florida           1          2

# %%
#Select the 3rd column up to the 7th column 
df.iloc[:,3:7]
# Out:
#             battles  size  veterans  readiness
# origin
# Arizona           5  1045         1          1
# California       42   957         5          2
# Texas             2  1099        62          3
# Florida           2  1400        26          3
# Maine             4  1592        73          2
# Iowa              7  1006        37          1
# Alaska            8   987       949          2
# Washington        3   849        48          3
# Oregon            4   973        48          2
# Wyoming           7  1005       435          1
# Louisana          8  1099        63          2
# Georgia           9  1523       345          3

# %%
#Select rows where df.deaths is greater than 50
df.loc[df['deaths']>50]
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Florida     Nighthawks     2nd     616        2  1400        26          3
# Iowa          Dragoons     1st     234        7  1006        37          1
# Alaska        Dragoons     2nd     523        8   987       949          2
# Washington    Dragoons     2nd      62        3   849        48          3
# Oregon          Scouts     1st      62        4   973        48          2
# Wyoming         Scouts     1st      73        7  1005       435          1
#
#             armored  deserters
# origin
# Arizona           1          4
# California        0         24
# Florida           1          2
# Iowa              1          4
# Alaska            0         24
# Washington        1         31
# Oregon            0          2
# ...

# %%
#Select all the regiments not named "Dragoons"
df.loc[df['regiment']!='Dragoons']
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Texas       Nighthawks     2nd      25        2  1099        62          3
# Florida     Nighthawks     2nd     616        2  1400        26          3
# Oregon          Scouts     1st      62        4   973        48          2
# Wyoming         Scouts     1st      73        7  1005       435          1
# Louisana        Scouts     2nd      37        8  1099        63          2
# Georgia         Scouts     2nd      35        9  1523       345          3
#
#             armored  deserters
# origin
# Arizona           1          4
# California        0         24
# Texas             1         31
# Florida           1          2
# Oregon            0          2
# Wyoming           0          3
# Louisana          1          2
# ...

# %%
#Select the rows called Texas and Arizona
df.loc[['Texas','Arizona']]
# Out:
#            regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Texas    Nighthawks     2nd      25        2  1099        62          3
# Arizona  Nighthawks     1st     523        5  1045         1          1
#
#          armored  deserters
# origin
# Texas          1         31
# Arizona        1          4

# %%
#Select the third cell in the row named Arizona #df.loc[['Arizona]].iloc[:, 2]
df.loc[['Arizona'],['deaths']]
# Out:
#          deaths
# origin
# Arizona     523

# %%
#Select the third cell down in the column named deaths  #df.loc[:, ['deaths]].iloc[2]
df.loc[['Texas'],['deaths']]
# Out:
#         deaths
# origin
# Texas       25

# %%
d50=df[df['deaths']<50]
d50
# Out:
#             regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Texas     Nighthawks     2nd      25        2  1099        62          3
# Maine       Dragoons     1st      43        4  1592        73          2
# Louisana      Scouts     2nd      37        8  1099        63          2
# Georgia       Scouts     2nd      35        9  1523       345          3
#
#           armored  deserters
# origin
# Texas           1         31
# Maine           0          3
# Louisana        1          2
# Georgia         1          3

# %%
d500=df[df['deaths']>500]
d500
# Out:
#            regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona  Nighthawks     1st     523        5  1045         1          1
# Florida  Nighthawks     2nd     616        2  1400        26          3
# Alaska     Dragoons     2nd     523        8   987       949          2
#
#          armored  deserters
# origin
# Arizona        1          4
# Florida        1          2
# Alaska         0         24

# %%
#Select rows where df.deaths is greater than 500 or less than 50
c=[d50, d500]
r=pd.concat(c)          #df.loc[(df['deaths']<50)|(df['deaths']>500)]
r
# Out:
#             regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Texas     Nighthawks     2nd      25        2  1099        62          3
# Maine       Dragoons     1st      43        4  1592        73          2
# Louisana      Scouts     2nd      37        8  1099        63          2
# Georgia       Scouts     2nd      35        9  1523       345          3
# Arizona   Nighthawks     1st     523        5  1045         1          1
# Florida   Nighthawks     2nd     616        2  1400        26          3
# Alaska      Dragoons     2nd     523        8   987       949          2
#
#           armored  deserters
# origin
# Texas           1         31
# Maine           0          3
# Louisana        1          2
# Georgia         1          3
# Arizona         1          4
# Florida         1          2
# Alaska          0         24

# %%
df
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Texas       Nighthawks     2nd      25        2  1099        62          3
# Florida     Nighthawks     2nd     616        2  1400        26          3
# Maine         Dragoons     1st      43        4  1592        73          2
# Iowa          Dragoons     1st     234        7  1006        37          1
# Alaska        Dragoons     2nd     523        8   987       949          2
# Washington    Dragoons     2nd      62        3   849        48          3
# Oregon          Scouts     1st      62        4   973        48          2
# Wyoming         Scouts     1st      73        7  1005       435          1
# Louisana        Scouts     2nd      37        8  1099        63          2
# ...

# %%
import matplotlib
import matplotlib.pyplot as plt
f = plt.figure()
f.set_figwidth(12)
plt.scatter(df.index, df.deaths)

# %%
f = plt.figure()
f.set_figwidth(12)
plt.bar(df.index, df.veterans)
# Out:
# <BarContainer object of 12 artists>

# %%
f = plt.figure()
f.set_figwidth(12)
plt.plot(df.index, df.deserters)

# %%
from numpy import nan 
df['veterans'] = df['veterans'].replace(26,np.nan)
df['deserters']=df['deserters'].replace(2,np.nan)
df['deaths'] = df['deaths'].replace(234,np.nan)
df
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st   523.0        5  1045       1.0          1
# California  Nighthawks     1st    52.0       42   957       5.0          2
# Texas       Nighthawks     2nd    25.0        2  1099      62.0          3
# Florida     Nighthawks     2nd   616.0        2  1400       NaN          3
# Maine         Dragoons     1st    43.0        4  1592      73.0          2
# Iowa          Dragoons     1st     NaN        7  1006      37.0          1
# Alaska        Dragoons     2nd   523.0        8   987     949.0          2
# Washington    Dragoons     2nd    62.0        3   849      48.0          3
# Oregon          Scouts     1st    62.0        4   973      48.0          2
# Wyoming         Scouts     1st    73.0        7  1005     435.0          1
# Louisana        Scouts     2nd    37.0        8  1099      63.0          2
# ...

# %%
import missingno as msno
msno.bar(df)

# %%
msno.heatmap(df)
