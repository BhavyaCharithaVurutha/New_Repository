# %%
import pandas as pd
import numpy as np
d= {"name": ['Bulbasaur', 'Charmander','Squirtle','Caterpie'],
            "evolution": ['Ivysaur','Charmeleon','Wartortle','Metapod'],
            "type": ['grass', 'fire', 'water', 'bug'],
            "hp": [45, 39, 44, 45],
            "pokedex": ['yes', 'no','yes','no']                        
            }
df=pd.DataFrame(data=d)
df
# Out:
#          name   evolution   type  hp pokedex
# 0   Bulbasaur     Ivysaur  grass  45     yes
# 1  Charmander  Charmeleon   fire  39      no
# 2    Squirtle   Wartortle  water  44     yes
# 3    Caterpie     Metapod    bug  45      no

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   name       4 non-null      object
#  1   evolution  4 non-null      object
#  2   type       4 non-null      object
#  3   hp         4 non-null      int64
#  4   pokedex    4 non-null      object
# dtypes: int64(1), object(4)
# memory usage: 288.0+ bytes

# %%
P=["Ambd","Blr","Vsk","Hyd"]
df["place"]=P
df
# Out:
#          name   evolution   type  hp pokedex place
# 0   Bulbasaur     Ivysaur  grass  45     yes  Ambd
# 1  Charmander  Charmeleon   fire  39      no   Blr
# 2    Squirtle   Wartortle  water  44     yes   Vsk
# 3    Caterpie     Metapod    bug  45      no   Hyd

# %%
df=df.reindex(columns=["name","type","hp","evolution","pokedex","place"])
df
# Out:
#          name   type  hp   evolution pokedex place
# 0   Bulbasaur  grass  45     Ivysaur     yes  Ambd
# 1  Charmander   fire  39  Charmeleon      no   Blr
# 2    Squirtle  water  44   Wartortle     yes   Vsk
# 3    Caterpie    bug  45     Metapod      no   Hyd

# %%
df.drop(columns=["pokedex"])
# Out:
#          name   type  hp   evolution place
# 0   Bulbasaur  grass  45     Ivysaur  Ambd
# 1  Charmander   fire  39  Charmeleon   Blr
# 2    Squirtle  water  44   Wartortle   Vsk
# 3    Caterpie    bug  45     Metapod   Hyd

# %%
from numpy import nan 
df['type'] = df['type'].replace('fire',np.nan)
df['hp']=df['hp'].replace(44,np.nan)
df
# Out:
#          name   type    hp   evolution pokedex place
# 0   Bulbasaur  grass  45.0     Ivysaur     yes  Ambd
# 1  Charmander    NaN  39.0  Charmeleon      no   Blr
# 2    Squirtle  water   NaN   Wartortle     yes   Vsk
# 3    Caterpie    bug  45.0     Metapod      no   Hyd

# %%
import missingno as msno
msno(df)

# %%
msno.matrix(df)
